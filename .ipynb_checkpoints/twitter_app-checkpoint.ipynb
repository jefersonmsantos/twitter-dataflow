# %%
API_Key = "7I8iprWZh5EKYzym1rd79BWLz"
API_Secret_key = "5PYCUpi4LpDHvSFpC918wiH2dkXUu7GNqtNzfs0SiUo42HPWHY"

bearer_token = "AAAAAAAAAAAAAAAAAAAAAPxgNgEAAAAAgJ10LrtDuhszyQ0lWwYPgyS9aBQ%3DVtcDGFHIwJoUWY9O2azFgrfXY8m9ZfCX7EgaOg3JUpeXCQeXSA"

access_token = "266944246-uoGQ0PdGUKGAnIkkeFRNrFpAv2tOfQ053TFrTT7C"
access_token_secret = "dm0bqi1lkhx3fZPDojs8LSHdhHHbnqXH2hxp1XtHDkkET"

# %%
#!py -m pip install tweepy
import tweepy
from datetime import datetime
import json
import pandas as pd

# %%
#Realizar autenticação no twitter
auth = tweepy.OAuthHandler(API_Key, API_Secret_key)
auth.set_access_token(access_token, access_token_secret)

#construir instância api
api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

# %%
api.update_status('HI test2')
# Out:
# Status(_api=<tweepy.api.API object at 0x00000206E3388E10>, _json={'created_at': 'Fri Mar 12 12:40:38 +0000 2021', 'id': 1370354042937958402, 'id_str': '1370354042937958402', 'text': 'HI test2', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://www.igti.com.br" rel="nofollow">test_igti_twitter_app</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 266944246, 'id_str': '266944246', 'name': 'Jeferson Santos', 'screen_name': 'Jefo0602', 'location': 'Porto Alegre', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 13, 'friends_count': 69, 'listed_count': 0, 'created_at': 'Wed Mar 16 02:25:52 +0000 2011', 'favourites_count': 9, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 
# ...

# %%
#Busca por palavras chave
#keyword = "'disney plus' OR 'disney+' OR 'disney +' OR '#disneyplus' OR '#disney+' OR 'netflix' OR '#netflix' OR 'globoplay' OR '#GLOBOPLAY' OR 'hbogo' OR 'hbo go' OR '#HBOGO' OR 'amazon prime' OR 'AMAZON PRIME VIDEO' OR '#primevideo' OR 'amazonprime'"
keyword = "'NETFLIX' OR 'HBOGO' OR 'DISNEYPLUS' OR 'DISNEY+' OR 'GLOBOPLAY' OR '#GLOBOPLAY'"
brasil_geo_code = api.geo_search(query="Brazil", granularity="country")[0].id

data_agora = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
out = open(f"collected_tweets_{data_agora}.txt","w")

cursor = tweepy.Cursor(api.search,
                          q='{} place:{}'.format(keyword, brasil_geo_code), 
                          #q=keyword,  
                          tweet_mode='extended',
                          rpp=1,
                          result_type="recent",
                          lang='pt',
                          include_entities=True,
                          include_rts=False).items(1)

for tweet in tweepy.Cursor(api.search,
                          q='{} place:{}'.format(keyword, brasil_geo_code), 
                          #q=keyword,  
                          tweet_mode='extended',
                          rpp=1,
                          result_type="recent",
                          lang='pt',
                          include_entities=True,
                          include_rts=False).items(1):
    
    itemstring=json.dumps(tweet._json)
    out.write(itemstring + '\n')

# %%
zero = next(cursor)
zero=iter([zero])

# %%
for a in zero:
    print(json.dumps(tweet._json))
# Out:
# {"created_at": "Thu Mar 18 12:24:50 +0000 2021", "id": 1372524394208235525, "id_str": "1372524394208235525", "full_text": "Assista #JornalDaEptv1\u00aaEdi\u00e7\u00e3oCampinaspiracicaba pelo #Globoplay https://t.co/KOesXYMv5U", "truncated": false, "display_text_range": [0, 87], "entities": {"hashtags": [{"text": "JornalDaEptv1\u00aaEdi\u00e7\u00e3oCampinaspiracicaba", "indices": [8, 47]}, {"text": "Globoplay", "indices": [53, 63]}], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/KOesXYMv5U", "expanded_url": "https://globoplay.globo.com/v/9357264/?utm_source=twitter&utm_medium=share-bar", "display_url": "globoplay.globo.com/v/9357264/?utm\u2026", "indices": [64, 87]}]}, "metadata": {"iso_language_code": "pt", "result_type": "recent"}, "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_
# ...

# %%
with open('collected_tweets_2021-03-12-10-21-11.txt', 'r') as file:
    tweets = file.readlines()
tweets
# Out:
# ['{"created_at": "Fri Mar 12 04:58:59 +0000 2021", "id": 1370237863556751360, "id_str": "1370237863556751360", "full_text": "Quase 02h da manh\\u00e3 e ainda \\u00f1 saiu ningu\\u00e9m... acho que essa prova vai durar heim! #bbb21aovivo #GloboPlay #Juliette #juliettecampea #CarlaDiaz #ProvaDoLider", "truncated": false, "display_text_range": [0, 155], "entities": {"hashtags": [{"text": "bbb21aovivo", "indices": [81, 93]}, {"text": "GloboPlay", "indices": [94, 104]}, {"text": "Juliette", "indices": [105, 114]}, {"text": "juliettecampea", "indices": [115, 130]}, {"text": "CarlaDiaz", "indices": [131, 141]}, {"text": "ProvaDoLider", "indices": [142, 155]}], "symbols": [], "user_mentions": [], "urls": []}, "metadata": {"iso_language_code": "pt", "result_type": "recent"}, "source": "<a href=\\"http://twitter.com/download/android\\" rel=\\"nofollow\\">Twitter for Android</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id
# ...

# %%
parsed_tweets = [json.loads(i) for i in tweets]
parsed_tweets
# Out:
# [{'created_at': 'Fri Mar 12 04:58:59 +0000 2021',
#   'id': 1370237863556751360,
#   'id_str': '1370237863556751360',
#   'full_text': 'Quase 02h da manhã e ainda ñ saiu ninguém... acho que essa prova vai durar heim! #bbb21aovivo #GloboPlay #Juliette #juliettecampea #CarlaDiaz #ProvaDoLider',
#   'truncated': False,
#   'display_text_range': [0, 155],
#   'entities': {'hashtags': [{'text': 'bbb21aovivo', 'indices': [81, 93]},
#     {'text': 'GloboPlay', 'indices': [94, 104]},
#     {'text': 'Juliette', 'indices': [105, 114]},
#     {'text': 'juliettecampea', 'indices': [115, 130]},
#     {'text': 'CarlaDiaz', 'indices': [131, 141]},
#     {'text': 'ProvaDoLider', 'indices': [142, 155]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
# ...

# %%
json.loads(tweets[0])
# Out:
# {'created_at': 'Fri Mar 12 04:58:59 +0000 2021',
#  'id': 1370237863556751360,
#  'id_str': '1370237863556751360',
#  'full_text': 'Quase 02h da manhã e ainda ñ saiu ninguém... acho que essa prova vai durar heim! #bbb21aovivo #GloboPlay #Juliette #juliettecampea #CarlaDiaz #ProvaDoLider',
#  'truncated': False,
#  'display_text_range': [0, 155],
#  'entities': {'hashtags': [{'text': 'bbb21aovivo', 'indices': [81, 93]},
#    {'text': 'GloboPlay', 'indices': [94, 104]},
#    {'text': 'Juliette', 'indices': [105, 114]},
#    {'text': 'juliettecampea', 'indices': [115, 130]},
#    {'text': 'CarlaDiaz', 'indices': [131, 141]},
#    {'text': 'ProvaDoLider', 'indices': [142, 155]}],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': []},
#  'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
# ...

# %%
with open('tweets_json.json','r') as f:
    parsed_tweets=json.load(f)

# %%
with open('tweet_json_2.json','w') as f:
    json.dump(parsed_tweets,f)

# %%
df = pd.json_normalize(parsed_tweets)
df
# Out:
#                        created_at                   id               id_str  \
# 0  Fri Mar 12 04:58:59 +0000 2021  1370237863556751360  1370237863556751360
# 1  Fri Mar 12 03:31:16 +0000 2021  1370215791455526917  1370215791455526917
# 2  Fri Mar 12 02:28:16 +0000 2021  1370199936688656384  1370199936688656384
# 3  Fri Mar 12 02:21:17 +0000 2021  1370198176683208706  1370198176683208706
# 4  Fri Mar 12 02:13:44 +0000 2021  1370196277225459727  1370196277225459727
# 5  Thu Mar 11 23:40:25 +0000 2021  1370157694586347536  1370157694586347536
# 6  Thu Mar 11 23:03:29 +0000 2021  1370148402554671104  1370148402554671104
# 7  Thu Mar 11 22:13:23 +0000 2021  1370135791893147651  1370135791893147651
#
#                                            full_text  truncated  \
# 0  Quase 02h da manhã e ainda ñ saiu ninguém... a...      False
# 1  Se eu usasse app pirata do zé da esquina o pay...      False
# 2  Quando eu for fofoca com minha cunhada @Patrci...      False
# ...

# %%
#SQL
#!py -m pip install pymysql
#!py -m pip install sqlalchemy
import pymysql
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://{user}:{pw}@statfoot.chvygiyeqqoe.us-east-2.rds.amazonaws.com:3306/{db}'
                      .format(user='jefo',
                             pw = 'fm4qkj2v',
                             db='twitter_app'))

connection = engine.connect()

for c in list(df.columns):
    df[c]=df[c].astype(str)

df.to_sql('tweets',con=connection,if_exists='append',index=False)

# %%
import pymysql
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://{user}:{pw}@statfoot.chvygiyeqqoe.us-east-2.rds.amazonaws.com:3306/{db}'
                      .format(user='jefo',
                             pw = 'fm4qkj2v',
                             db='twitter_app'))

connection = engine.connect()

# %%
connection.execute("SELECT * FROM tweets LIMIT 1")._metadata.keys
# Out:
# ['created_at',
#  'id',
#  'id_str',
#  'full_text',
#  'truncated',
#  'display_text_range',
#  'source',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'in_reply_to_screen_name',
#  'geo',
#  'coordinates',
#  'contributors',
#  'is_quote_status',
#  'retweet_count',
#  'favorite_count',
#  'favorited',
#  'retweeted',
#  'lang',
#  'entities.hashtags',
#  'entities.symbols',
#  'entities.user_mentions',
#  'entities.urls',
#  'metadata.iso_language_code',
#  'metadata.result_type',
#  'user.id',
#  'user.id_str',
#  'user.name',
#  'user.screen_name',
#  'user.location',
#  'user.description',
#  'user.url',
#  'user.entities.description.urls',
#  'user.protected',
#  'user.followers_count',
#  'user.friends_count',
#  'user.listed_count',
#  'user.created_at',
#  'user.favourites_count',
#  'user.utc_offset',
#  'user.time_zone',
#  'user.geo_enabled',
#  'user.verified',
#  'user.statuses_count',
# ...

# %%
import pymysql.cursors

# %%
cursor = engine.cursor()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-4d17a95a07fc> in <module>
# ----> 1 cursor = engine.cursor()
#
# AttributeError: 'Engine' object has no attribute 'cursor'

# %%
from sqlalchemy.orm import sessionmaker

Session = sessionmaker(bind=engine)
session = Session()

query = session.query().all()
query
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-22-00d2bf7a7bee> in <module>
#       4 session = Session()
#       5
# ----> 6 query = session.query().all()
#       7 query
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\orm\query.py in all(self)
#    3371                 :ref:`faq_query_deduplicating`
#    3372         """
# -> 3373         return list(self)
#    3374
#    3375     @_generative(_no_clauseelement_condition)
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\sqlalchemy\orm\query.py in __iter__(self)
#    3529
#    3530     def __iter__(self):
# -> 3531         context = self._compile_context()
#    3532         context.statement.use_labels = True
#    3533         if self._autoflush and not self._populate_existing:
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 83 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   created_at                               8 non-null      object
#  1   id                                       8 non-null      int64
#  2   id_str                                   8 non-null      object
#  3   full_text                                8 non-null      object
#  4   truncated                                8 non-null      bool
#  5   display_text_range                       8 non-null      object
#  6   source                                   8 non-null      object
#  7   in_reply_to_status_id                    0 non-null      object
#  8   in_reply_to_status_id_str                0 non-null      object
#  9   in_reply_to_user_id                      1 non-null      float64
# ...

# %%
with open('tweets_json.json','w') as f:
    json.dump(parsed_tweets, f)

# %%
places = api.geo_search(query="Brazil", granularity="country")
places[0].id
# Out:
# '1b107df3ccc0aaa1'

# %%
json.dumps(tweet._json)
# Out:
# '{"created_at": "Fri Mar 12 12:01:14 +0000 2021", "id": 1370344127251017728, "id_str": "1370344127251017728", "full_text": "Fiuk caiu mais feio do que o #Globoplay quando tem evento importante no #BBB21 https://t.co/1rhN8AKmjq", "truncated": false, "display_text_range": [0, 78], "entities": {"hashtags": [{"text": "Globoplay", "indices": [29, 39]}, {"text": "BBB21", "indices": [72, 78]}], "symbols": [], "user_mentions": [], "urls": [], "media": [{"id": 1370343992370561027, "id_str": "1370343992370561027", "indices": [79, 102], "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1370343992370561027/pu/img/6VSF1qPf4hhTezVP.jpg", "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1370343992370561027/pu/img/6VSF1qPf4hhTezVP.jpg", "url": "https://t.co/1rhN8AKmjq", "display_url": "pic.twitter.com/1rhN8AKmjq", "expanded_url": "https://twitter.com/pitacors/status/1370344127251017728/video/1", "type": "photo", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "medium": {"w
# ...

# %%
# !py -m pip install python-dotenv
from dotenv import load_dotenv
import os

load_dotenv("dags/.env")

sql_pw = os.getenv("sql_pw")
sql_user = os.getenv("sql_user")

print(sql_user)
print(sql_pw)
# Out:
# ...
# jefo
# fm4qkj2v
